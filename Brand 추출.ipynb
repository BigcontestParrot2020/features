# %%
import pandas as pd
import numpy as np
import sklearn
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
import seaborn as sns

# %%
from sklearn.preprocessing import MinMaxScaler
print('Pandas : %s'%(pd.__version__))
print('Numpy : %s'%(np.__version__))
print('Scikit-Learn : %s'%(sklearn.__version__))
# !python --version
# Out:
# Pandas : 1.0.2
# Numpy : 1.18.1
# Scikit-Learn : 0.22.1
# Python 3.7.6

# %%
beauty = pd.read_csv('beauty.csv')
bed = pd.read_csv('bed.csv')
clothes = pd.read_csv('clothes.csv')
digital = pd.read_csv('digital.csv')
furniture = pd.read_csv('furniture.csv')
health = pd.read_csv('health.csv')
inner = pd.read_csv('inner.csv')
kithchen = pd.read_csv('kitchen.csv')
life = pd.read_csv('life.csv')
stuff = pd.read_csv('stuff.csv')

# %%
beauty = list(np.array(beauty['0'].tolist()))
bed = list(np.array(bed['0'].tolist()))
clothes = list(np.array(clothes['0'].tolist()))
digital = list(np.array(digital['0'].tolist()))
furniture = list(np.array(furniture['0'].tolist()))
health = list(np.array(health['0'].tolist()))
inner = list(np.array(inner['0'].tolist()))
kitchen = list(np.array(kithchen['0'].tolist()))
life = list(np.array(life['0'].tolist()))
stuff = list(np.array(stuff['0'].tolist()))

# %%
clothes.remove('CERINI_by_PAT')

# %%
clothes.append('CERINI by PAT')

# %%
data = pd.read_excel('2020 빅콘테스트 데이터분석분야-챔피언리그_2019년 실적데이터_v1_200818.xlsx', header=1)
data.head()
# Out:
#                  방송일시  노출(분)    마더코드    상품코드            상품명 상품군   판매단가  \
# 0 2019-01-01 06:00:00   20.0  100346  201072  테이트 남성 셀린니트3종  의류  39900
# 1 2019-01-01 06:00:00    NaN  100346  201079  테이트 여성 셀린니트3종  의류  39900
# 2 2019-01-01 06:20:00   20.0  100346  201072  테이트 남성 셀린니트3종  의류  39900
# 3 2019-01-01 06:20:00    NaN  100346  201079  테이트 여성 셀린니트3종  의류  39900
# 4 2019-01-01 06:40:00   20.0  100346  201072  테이트 남성 셀린니트3종  의류  39900
#
#          취급액
# 0  2099000.0
# 1  4371000.0
# 2  3262000.0
# 3  6955000.0
# 4  6672000.0

# %%
data['상품군'].value_counts()
# Out:
# 주방      6604
# 가전      6479
# 의류      4340
# 속옷      3919
# 잡화      3891
# 농수축     3884
# 생활용품    2877
# 가구      2614
# 이미용     1305
# 무형       937
# 건강기능     790
# 침구       669
# Name: 상품군, dtype: int64

# %%
data['상품명'].iloc[2]
# Out:
# '테이트 남성 셀린니트3종'

# %%
data[(data.상품군 == '생활용품') & (data.상품명.str.contains('실속패키지'))]

# %%
g = data['상품군'].iloc[0]
n = data['상품명'].iloc[0]
print(g)
print(n)
# Out:
# 의류
# 테이트 남성 셀린니트3종

# %%
data = pd.read_csv('0921_ver.csv', header=0)
data
# Out:
#                       방송일시  노출(분)             상품명 상품군    판매단가         취급액   월  \
# 0      2019-01-01 06:00:00   20.0   테이트 남성 셀린니트3종  의류   39900   2099000.0   1
# 1      2019-01-01 06:00:00   20.0   테이트 여성 셀린니트3종  의류   39900   4371000.0   1
# 2      2019-01-01 06:20:00   20.0   테이트 남성 셀린니트3종  의류   39900   3262000.0   1
# 3      2019-01-01 06:20:00   20.0   테이트 여성 셀린니트3종  의류   39900   6955000.0   1
# 4      2019-01-01 06:40:00   20.0   테이트 남성 셀린니트3종  의류   39900   6672000.0   1
# ...                    ...    ...             ...  ..     ...         ...  ..
# 35370  2019-12-31 23:20:00   20.0   일시불쿠첸압력밥솥 6인용  주방  148000   1664000.0  12
# 35371  2019-12-31 23:40:00   20.0  무이자쿠첸압력밥솥 10인용  주방  178000   9149000.0  12
# 35372  2019-12-31 23:40:00   20.0  일시불쿠첸압력밥솥 10인용  주방  168000  15282000.0  12
# 35373  2019-12-31 23:40:00   20.0   무이자쿠첸압력밥솥 6인용  주방  158000   2328000.0  12
# 35374  2019-12-31 23:40:00   20.0   일시불쿠첸압력밥솥 6인용  주방  148000  10157000.0  12
#
#         일   시  소비층       요일  휴일  프라임      파트
# 0       1   6    1  Tuesday   2    4   First
# 1       1   6    1  Tuesday   2    4   First
# 2       1   6    1  Tuesday   2    4  Middle
# 3       1   6    1  Tuesday   2    4  Middle
# 4       1   6    1  Tuesday   2    4   Later
# ...    ..  ..  ...      ...  ..  ...     ...
# 35370  31  23    2  Tuesday   0    4   First
# 35371  31  23    2  Tuesday   0    4   Later
# 35372  31  23    2  Tuesday   0    4   Later
# 35373  31  23    2  Tuesday   0    4   Later
# 35374  31  23    2  Tuesday   0    4   Later
#
# [35375 rows x 14 columns]

# %%
def Brand(group, name):
    for brand in group:
        if brand in name:
            return brand
#         else:
#             return 'X'

# %%
brand_list = []
for i in range(len(data)):
    group = data['상품군'].iloc[i]
    name = data['상품명'].iloc[i]
    
    if group == '주방':
        brand_list.append(Brand(kitchen, name))
    elif group == '가전':
        brand_list.append(Brand(digital, name))
    elif group == '의류':
        brand_list.append(Brand(clothes, name))
    elif group == '속옷':
        brand_list.append(Brand(inner, name))
    elif group == '잡화':
        brand_list.append(Brand(stuff, name))
    elif group == '생활용품':
        brand_list.append(Brand(life, name))
    elif group == '가구':
        brand_list.append(Brand(furniture, name))
    elif group == '이미용':
        brand_list.append(Brand(beauty, name))
    elif group == '건강기능':
        brand_list.append(Brand(health, name))
    elif group == '침구':
        brand_list.append(Brand(bed, name))
    else:
        brand_list.append('X')

# %%
brand_list
# Out:
# ['테이트',
#  '테이트',
#  '테이트',
#  '테이트',
#  '테이트',
#  '테이트',
#  '오모떼',
#  '오모떼',
#  '오모떼',
#  'CERINI by PAT',
#  'CERINI by PAT',
#  'CERINI by PAT',
#  '보코',
#  '보코',
#  '보코',
#  'CERINI by PAT',
#  'CERINI by PAT',
#  'CERINI by PAT',
#  '크로커다일',
#  '크로커다일',
#  '에코라믹',
#  '에코라믹',
#  '에코라믹',
#  '오모떼',
#  '오모떼',
#  '그렉노먼',
#  '그렉노먼',
#  '그렉노먼',
#  '그렉노먼',
#  'X',
#  'X',
#  'X',
#  'X',
#  'X',
#  'X',
#  '비버리힐스폴로클럽',
#  '비버리힐스폴로클럽',
#  '비버리힐스폴로클럽',
#  'X',
#  'X',
#  'X',
#  '푸마',
#  '푸마',
#  '푸마',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  '마리노블',
#  '마리노블',
#  '마리노블',
#  '헤스티지',
#  '헤스티지',
#  '로베르타',
#  '로베르타',
#  '로베르타',
#  '그렉노먼',
#  '그렉노먼',
#  '그렉노먼',
#  '그렉노먼',
#  '그렉노먼',
#  '그렉노먼',
#  '레이프릴',
#  '레이프릴',
#  '레이프릴',
#  '벨라홈',
#  '벨라홈',
#  '벨라홈',
#  '종근당건강',
#  '종근당건강',
#  '종근당건강',
#  '오모떼',
#  '오모떼',
#  '오모떼',
#  'NNF',
#  'NNF',
#  'NNF',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '헤스티지',
#  '헤스티지',
#  '린나이',
#  '린나이',
#  '린나이',
#  '린나이',
#  '린나이',
#  '린나이',
#  '린나이',
#  '린나이',
#  '린나이',
#  '린나이',
#  '린나이',
#  '린나이',
#  'X',
#  'X',
#  'X',
#  '오모떼',
#  '오모떼',
#  'X',
#  'X',
#  'X',
#  'X',
#  'X',
#  'X',
#  'X',
#  'X',
#  'X',
#  'X',
#  'X',
#  'X',
#  '키친플라워',
#  '키친플라워',
#  '키친플라워',
#  'X',
#  'X',
#  'X',
#  '푸마',
#  '푸마',
#  '푸마',
#  '푸마',
#  '푸마',
#  '푸마',
#  '푸마',
#  '푸마',
#  '푸마',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  '크로커다일',
#  '크로커다일',
#  '크로커다일',
#  '테이트',
#  '테이트',
#  '테이트',
#  '테이트',
#  '푸마',
#  '푸마',
#  '푸마',
#  '에펨',
#  '에펨',
#  '에펨',
#  '에펨',
#  '에펨',
#  '에펨',
#  'X',
#  'X',
#  'X',
#  '엘렌실라',
#  '엘렌실라',
#  '엘렌실라',
#  '로베르타',
#  '로베르타',
#  '로베르타',
#  '오모떼',
#  '오모떼',
#  '보코',
#  '보코',
#  '보코',
#  '종근당건강',
#  '종근당건강',
#  '종근당건강',
#  '비버리힐스폴로클럽',
#  '비버리힐스폴로클럽',
#  '비버리힐스폴로클럽',
#  '한일',
#  '한일',
#  '한일',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  'X',
#  'X',
#  'X',
#  'X',
#  'X',
#  'X',
#  'X',
#  'X',
#  'X',
#  '푸마',
#  '푸마',
#  '푸마',
#  '푸마',
#  '푸마',
#  '푸마',
#  '푸마',
#  '푸마',
#  '푸마',
#  '노비타',
#  '노비타',
#  '노비타',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  '로베르타',
#  '로베르타',
#  '로베르타',
#  '그렉노먼',
#  '그렉노먼',
#  '그렉노먼',
#  '그렉노먼',
#  '그렉노먼',
#  '그렉노먼',
#  '마리노블',
#  '마리노블',
#  '마리노블',
#  '벨라홈',
#  '벨라홈',
#  '벨라홈',
#  '제주농장',
#  '제주농장',
#  '제주농장',
#  '코이모',
#  '코이모',
#  '코이모',
#  '로베르타',
#  '로베르타',
#  '로베르타',
#  '린나이',
#  '린나이',
#  '린나이',
#  '린나이',
#  '린나이',
#  '린나이',
#  '린나이',
#  '린나이',
#  '린나이',
#  '린나이',
#  '린나이',
#  '린나이',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '오모떼',
#  '오모떼',
#  'X',
#  'X',
#  'X',
#  '한일',
#  '한일',
#  '한일',
#  '오모떼',
#  '오모떼',
#  '오모떼',
#  'X',
#  'X',
#  'X',
#  'X',
#  'X',
#  'X',
#  '키친플라워',
#  '키친플라워',
#  '키친플라워',
#  'X',
#  'X',
#  'X',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  '비버리힐스폴로클럽',
#  '비버리힐스폴로클럽',
#  '비버리힐스폴로클럽',
#  '크로커다일',
#  '크로커다일',
#  '크로커다일',
#  '그렉노먼',
#  '그렉노먼',
#  '그렉노먼',
#  '그렉노먼',
#  '그렉노먼',
#  '그렉노먼',
#  '헤스티지',
#  '헤스티지',
#  '스포메틱스',
#  '스포메틱스',
#  '스포메틱스',
#  '가이거',
#  '가이거',
#  '가이거',
#  '가이거',
#  '가이거',
#  '가이거',
#  '스칼프솔루션',
#  '스칼프솔루션',
#  '스칼프솔루션',
#  '아문센',
#  '아문센',
#  '아문센',
#  '아문센',
#  '아문센',
#  '아문센',
#  '마담팰리스',
#  '마담팰리스',
#  '마담팰리스',
#  '오모떼',
#  '오모떼',
#  '보코',
#  '보코',
#  '보코',
#  'CERINI by PAT',
#  'CERINI by PAT',
#  'CERINI by PAT',
#  '키친플라워',
#  '키친플라워',
#  '키친플라워',
#  '에코라믹',
#  '에코라믹',
#  '에코라믹',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  '오모떼',
#  '오모떼',
#  'X',
#  'X',
#  'X',
#  'X',
#  'X',
#  'X',
#  'X',
#  'X',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '푸마',
#  '푸마',
#  '푸마',
#  '푸마',
#  '푸마',
#  '푸마',
#  '푸마',
#  '푸마',
#  '푸마',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  '푸마',
#  '푸마',
#  '푸마',
#  'K-SWISS',
#  'K-SWISS',
#  'K-SWISS',
#  'K-SWISS',
#  'K-SWISS',
#  'K-SWISS',
#  '비버리힐스폴로클럽',
#  '비버리힐스폴로클럽',
#  '비버리힐스폴로클럽',
#  'X',
#  'X',
#  'X',
#  '종근당건강',
#  '종근당건강',
#  '종근당건강',
#  '마리끌레르',
#  '마리끌레르',
#  '마리끌레르',
#  '로베르타',
#  '로베르타',
#  '로베르타',
#  '보코',
#  '보코',
#  '보코',
#  '오모떼',
#  '오모떼',
#  '오모떼',
#  '헤스티지',
#  '헤스티지',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '아리스토우',
#  '아리스토우',
#  '아리스토우',
#  '비버리힐스폴로클럽',
#  '비버리힐스폴로클럽',
#  '비버리힐스폴로클럽',
#  '오모떼',
#  '오모떼',
#  'X',
#  'X',
#  'X',
#  'X',
#  'X',
#  'X',
#  '푸마',
#  '푸마',
#  '푸마',
#  '푸마',
#  '푸마',
#  '푸마',
#  '푸마',
#  '푸마',
#  '푸마',
#  '노비타',
#  '노비타',
#  '노비타',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  '크로커다일',
#  '크로커다일',
#  '크로커다일',
#  '마리노블',
#  '마리노블',
#  '마리노블',
#  '스위스밀리터리',
#  '스위스밀리터리',
#  '도네이',
#  '도네이',
#  '도네이',
#  '도네이',
#  '도네이',
#  '도네이',
#  '레이프릴',
#  '레이프릴',
#  '레이프릴',
#  '엘렌실라',
#  '엘렌실라',
#  '엘렌실라',
#  '보코',
#  '보코',
#  '보코',
#  '비버리힐스폴로클럽',
#  '비버리힐스폴로클럽',
#  '비버리힐스폴로클럽',
#  '오모떼',
#  '오모떼',
#  '린나이',
#  '린나이',
#  '린나이',
#  '린나이',
#  '린나이',
#  '린나이',
#  '린나이',
#  '린나이',
#  '린나이',
#  '린나이',
#  '린나이',
#  '린나이',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  'X',
#  'X',
#  'X',
#  '한일',
#  '한일',
#  '한일',
#  'X',
#  'X',
#  'X',
#  'X',
#  'X',
#  'X',
#  '에코라믹',
#  '에코라믹',
#  '에코라믹',
#  'X',
#  'X',
#  'X',
#  '노비타',
#  '노비타',
#  '노비타',
#  '푸마',
#  '푸마',
#  '푸마',
#  '푸마',
#  '푸마',
#  '푸마',
#  '푸마',
#  '푸마',
#  '푸마',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  '로베르타',
#  '로베르타',
#  '로베르타',
#  '헤스티지',
#  '헤스티지',
#  'K-SWISS',
#  'K-SWISS',
#  'K-SWISS',
#  'K-SWISS',
#  'K-SWISS',
#  'K-SWISS',
#  '푸마',
#  '푸마',
#  '푸마',
#  '스칼프솔루션',
#  '스칼프솔루션',
#  '스칼프솔루션',
#  '마담팰리스',
#  '마담팰리스',
#  '마담팰리스',
#  '쿠미투니카',
#  '쿠미투니카',
#  '엘렌실라',
#  '엘렌실라',
#  '엘렌실라',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '오모떼',
#  '오모떼',
#  'X',
#  'X',
#  'X',
#  'X',
#  'X',
#  'X',
#  'X',
#  'X',
#  'X',
#  'X',
#  'X',
#  'X',
#  '키친플라워',
#  '키친플라워',
#  '키친플라워',
#  'X',
#  'X',
#  'X',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '푸마',
#  '푸마',
#  '푸마',
#  '푸마',
#  '푸마',
#  '푸마',
#  '푸마',
#  '푸마',
#  '푸마',
#  'X',
#  'X',
#  'X',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  '마리노블',
#  '마리노블',
#  '마리노블',
#  '크로커다일',
#  '크로커다일',
#  '크로커다일',
#  '아리스토우',
#  '아리스토우',
#  '아리스토우',
#  '가이거',
#  '가이거',
#  '가이거',
#  '가이거',
#  '가이거',
#  '가이거',
#  '보코',
#  '보코',
#  '보코',
#  '종근당건강',
#  '종근당건강',
#  '종근당건강',
#  '레이프릴',
#  '레이프릴',
#  '레이프릴',
#  '린나이',
#  '린나이',
#  '린나이',
#  '린나이',
#  '린나이',
#  '린나이',
#  '린나이',
#  '린나이',
#  '린나이',
#  '린나이',
#  '린나이',
#  '린나이',
#  '엘렌실라',
#  '엘렌실라',
#  '엘렌실라',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '에코라믹',
#  '에코라믹',
#  'X',
#  'X',
#  'X',
#  'X',
#  'X',
#  'X',
#  '한일',
#  '한일',
#  '한일',
#  'X',
#  'X',
#  'X',
#  'X',
#  'X',
#  'X',
#  'X',
#  'X',
#  'X',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  '노비타',
#  '노비타',
#  '노비타',
#  '로베르타',
#  '로베르타',
#  '로베르타',
#  '헤스티지',
#  '헤스티지',
#  'CERINI by PAT',
#  'CERINI by PAT',
#  'CERINI by PAT',
#  '비버리힐스폴로클럽',
#  '비버리힐스폴로클럽',
#  '비버리힐스폴로클럽',
#  '레이프릴',
#  '레이프릴',
#  '레이프릴',
#  '메디쉴드',
#  '메디쉴드',
#  '메디쉴드',
#  '메디쉴드',
#  '메디쉴드',
#  '메디쉴드',
#  '마담팰리스',
#  '마담팰리스',
#  '마담팰리스',
#  '아리스토우',
#  '아리스토우',
#  '아리스토우',
#  '오모떼',
#  '오모떼',
#  '린나이',
#  '린나이',
#  '린나이',
#  '린나이',
#  '린나이',
#  '린나이',
#  '린나이',
#  '린나이',
#  '린나이',
#  '린나이',
#  '린나이',
#  '린나이',
#  '종근당건강',
#  '종근당건강',
#  '종근당건강',
#  'X',
#  'X',
#  'X',
#  '키친플라워',
#  '키친플라워',
#  '키친플라워',
#  'X',
#  'X',
#  'X',
#  'X',
#  'X',
#  'X',
#  'X',
#  'X',
#  'X',
#  'X',
#  'X',
#  'X',
#  'X',
#  'X',
#  'X',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '크로커다일',
#  '크로커다일',
#  '크로커다일',
#  'X',
#  'X',
#  'X',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  '마리노블',
#  '마리노블',
#  '마리노블',
#  '레이프릴',
#  '레이프릴',
#  '레이프릴',
#  '마리끌레르',
#  '마리끌레르',
#  '마리끌레르',
#  '에버라스트',
#  '에버라스트',
#  '에버라스트',
#  '에버라스트',
#  '에버라스트',
#  '에버라스트',
#  '테이트',
#  '테이트',
#  '테이트',
#  '테이트',
#  '테이트',
#  '테이트',
#  '오모떼',
#  '오모떼',
#  '보코',
#  '보코',
#  '보코',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '더블유베일',
#  '더블유베일',
#  'X',
#  'X',
#  'X',
#  '한일',
#  '한일',
#  '한일',
#  'X',
#  'X',
#  'X',
#  'X',
#  'X',
#  'X',
#  'X',
#  'X',
#  'X',
#  'X',
#  'X',
#  'X',
#  '키친플라워',
#  '키친플라워',
#  '키친플라워',
#  '카파',
#  '카파',
#  '카파',
#  '카파',
#  '카파',
#  '카파',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'CERINI by PAT',
#  'CERINI by PAT',
#  'CERINI by PAT',
#  '로이몬스터',
#  '로이몬스터',
#  '삼성',
#  '삼성',
#  '삼성',
#  '삼성',
#  '삼성',
#  '삼성',
#  '삼성',
#  '삼성',
#  '삼성',
#  '삼성',
#  '아리스토우',
#  '아리스토우',
#  '아리스토우',
#  '아리스토우',
#  '아리스토우',
#  '아리스토우',
#  '그렉노먼',
#  '그렉노먼',
#  '그렉노먼',
#  '그렉노먼',
#  '그렉노먼',
#  '그렉노먼',
#  '보코',
#  '보코',
#  '보코',
#  '쿠미투니카',
#  '쿠미투니카',
#  '쿠미투니카',
#  '가이거',
#  '가이거',
#  '가이거',
#  '가이거',
#  '가이거',
#  '가이거',
#  'CERINI by PAT',
#  'CERINI by PAT',
#  'CERINI by PAT',
#  '헤스티지',
#  '헤스티지',
#  '오모떼',
#  '오모떼',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '비버리힐스폴로클럽',
#  '비버리힐스폴로클럽',
#  '비버리힐스폴로클럽',
#  '린나이',
#  ...]

# %%
data['브랜드'] = brand_list
data
# Out:
#                       방송일시  노출(분)             상품명 상품군    판매단가         취급액   월  \
# 0      2019-01-01 06:00:00   20.0   테이트 남성 셀린니트3종  의류   39900   2099000.0   1
# 1      2019-01-01 06:00:00   20.0   테이트 여성 셀린니트3종  의류   39900   4371000.0   1
# 2      2019-01-01 06:20:00   20.0   테이트 남성 셀린니트3종  의류   39900   3262000.0   1
# 3      2019-01-01 06:20:00   20.0   테이트 여성 셀린니트3종  의류   39900   6955000.0   1
# 4      2019-01-01 06:40:00   20.0   테이트 남성 셀린니트3종  의류   39900   6672000.0   1
# ...                    ...    ...             ...  ..     ...         ...  ..
# 35370  2019-12-31 23:20:00   20.0   일시불쿠첸압력밥솥 6인용  주방  148000   1664000.0  12
# 35371  2019-12-31 23:40:00   20.0  무이자쿠첸압력밥솥 10인용  주방  178000   9149000.0  12
# 35372  2019-12-31 23:40:00   20.0  일시불쿠첸압력밥솥 10인용  주방  168000  15282000.0  12
# 35373  2019-12-31 23:40:00   20.0   무이자쿠첸압력밥솥 6인용  주방  158000   2328000.0  12
# 35374  2019-12-31 23:40:00   20.0   일시불쿠첸압력밥솥 6인용  주방  148000  10157000.0  12
#
#         일   시  소비층       요일  휴일  프라임      파트  브랜드
# 0       1   6    1  Tuesday   2    4   First  테이트
# 1       1   6    1  Tuesday   2    4   First  테이트
# 2       1   6    1  Tuesday   2    4  Middle  테이트
# 3       1   6    1  Tuesday   2    4  Middle  테이트
# 4       1   6    1  Tuesday   2    4   Later  테이트
# ...    ..  ..  ...      ...  ..  ...     ...  ...
# 35370  31  23    2  Tuesday   0    4   First   쿠첸
# 35371  31  23    2  Tuesday   0    4   Later   쿠첸
# 35372  31  23    2  Tuesday   0    4   Later   쿠첸
# 35373  31  23    2  Tuesday   0    4   Later   쿠첸
# 35374  31  23    2  Tuesday   0    4   Later   쿠첸
#
# [35375 rows x 15 columns]

# %%
data.head(50)
# Out:
#                    방송일시  노출(분)                            상품명  상품군    판매단가  \
# 0   2019-01-01 06:00:00   20.0                  테이트 남성 셀린니트3종   의류   39900
# 1   2019-01-01 06:00:00   20.0                  테이트 여성 셀린니트3종   의류   39900
# 2   2019-01-01 06:20:00   20.0                  테이트 남성 셀린니트3종   의류   39900
# 3   2019-01-01 06:20:00   20.0                  테이트 여성 셀린니트3종   의류   39900
# 4   2019-01-01 06:40:00   20.0                  테이트 남성 셀린니트3종   의류   39900
# 5   2019-01-01 06:40:00   20.0                  테이트 여성 셀린니트3종   의류   39900
# 6   2019-01-01 07:00:00   20.0               오모떼 레이스 파운데이션 브라   속옷   59000
# 7   2019-01-01 07:20:00   20.0               오모떼 레이스 파운데이션 브라   속옷   59000
# 8   2019-01-01 07:40:00   20.0               오모떼 레이스 파운데이션 브라   속옷   59000
# 9   2019-01-01 08:00:00   20.0  CERINI by PAT 남성 소프트 기모 릴렉스팬츠   의류   59900
# 10  2019-01-01 08:20:00   20.0  CERINI by PAT 남성 소프트 기모 릴렉스팬츠   의류   59900
# 11  2019-01-01 08:40:00   20.0  CERINI by PAT 남성 소프트 기모 릴렉스팬츠   의류   59900
# 12  2019-01-01 09:00:00   20.0                    보코 리버시블 무스탕   의류   79000
# 13  2019-01-01 09:20:00   20.0                    보코 리버시블 무스탕   의류   79000
# 14  2019-01-01 09:40:00   20.0                    보코 리버시블 무스탕   의류   79000
# 15  2019-01-01 10:00:00   20.0  CERINI by PAT 남성 풀패키지 기모니트 3종   의류   79900
# 16  2019-01-01 10:20:00   20.0  CERINI by PAT 남성 풀패키지 기모니트 3종   의류   79900
# 17  2019-01-01 10:40:00   20.0  CERINI by PAT 남성 풀패키지 기모니트 3종   의류   79900
# 18  2019-01-01 11:00:00   20.0      크로커다일 The 편안한 코튼 브라팬티 4세트   속옷   69900
# 19  2019-01-01 11:20:00   20.0      크로커다일 The 편안한 코튼 브라팬티 4세트   속옷   69900
# 20  2019-01-01 12:00:00   20.0               에코라믹 통주물 스톤 냄비세트   주방   60900
# 21  2019-01-01 12:20:00   20.0               에코라믹 통주물 스톤 냄비세트   주방   60900
# 22  2019-01-01 12:40:00   20.0               에코라믹 통주물 스톤 냄비세트   주방   60900
# 23  2019-01-01 13:00:00   30.0       오모떼 360도 텐션업 레이스 패키지 시즌4   속옷  109000
# 24  2019-01-01 13:30:00   30.0       오모떼 360도 텐션업 레이스 패키지 시즌4   속옷  109000
# 25  2019-01-01 14:00:00   30.0            그렉노먼 남성 구스다운 롱 벤치코트   의류  119000
# 26  2019-01-01 14:00:00   30.0            그렉노먼 여성 구스다운 롱 벤치코트   의류  119000
# 27  2019-01-01 14:30:00   30.0            그렉노먼 남성 구스다운 롱 벤치코트   의류  119000
# 28  2019-01-01 14:30:00   30.0            그렉노먼 여성 구스다운 롱 벤치코트   의류  119000
# 29  2019-01-01 15:00:00   20.0               뽕셰프 이봉원 특갈비탕 12팩  농수축   60900
# 30  2019-01-01 15:20:00   20.0               뽕셰프 이봉원 특갈비탕 12팩  농수축   60900
# 31  2019-01-01 15:40:00   20.0               뽕셰프 이봉원 특갈비탕 12팩  농수축   60900
# 32  2019-01-01 16:00:00   20.0                  국내산 손질갑오징어 8팩  농수축   49900
# 33  2019-01-01 16:20:00   20.0                  국내산 손질갑오징어 8팩  농수축   49900
# 34  2019-01-01 16:40:00   20.0              멋진밥상 흥양농협 햅쌀 20kg  농수축   61000
# 35  2019-01-01 17:00:00   20.0     비버리힐스폴로클럽 남성기초세트(2018FW골드)  이미용   39800
# 36  2019-01-01 17:20:00   20.0     비버리힐스폴로클럽 남성기초세트(2018FW골드)  이미용   39800
# 37  2019-01-01 17:40:00   20.0     비버리힐스폴로클럽 남성기초세트(2018FW골드)  이미용   39800
# 38  2019-01-01 18:00:00   20.0                 우리바다 손질왕꼬막 24팩  농수축   39900
# 39  2019-01-01 18:20:00   20.0                 우리바다 손질왕꼬막 24팩  농수축   39900
# 40  2019-01-01 18:40:00   20.0                 우리바다 손질왕꼬막 24팩  농수축   39900
# 41  2019-01-01 19:00:00   20.0         푸마 에어핏 서포트 브라세트 15종+4종   속옷  119000
# 42  2019-01-01 19:20:00   20.0         푸마 에어핏 서포트 브라세트 15종+4종   속옷  119000
# 43  2019-01-01 19:40:00   20.0         푸마 에어핏 서포트 브라세트 15종+4종   속옷  119000
# 44  2019-01-01 20:00:00   20.0                 일시불 LG 통돌이 세탁기   가전  439000
# 45  2019-01-01 20:00:00   20.0                 무이자 LG 통돌이 세탁기   가전  489000
# 46  2019-01-01 20:20:00   20.0                 일시불 LG 통돌이 세탁기   가전  439000
# 47  2019-01-01 20:20:00   20.0                 무이자 LG 통돌이 세탁기   가전  489000
# 48  2019-01-01 20:40:00   20.0                 일시불 LG 통돌이 세탁기   가전  439000
# 49  2019-01-01 20:40:00   20.0                 무이자 LG 통돌이 세탁기   가전  489000
#
#             취급액  월  일   시  소비층       요일  휴일  프라임      파트            브랜드
# 0     2099000.0  1  1   6    1  Tuesday   2    4   First            테이트
# 1     4371000.0  1  1   6    1  Tuesday   2    4   First            테이트
# 2     3262000.0  1  1   6    1  Tuesday   2    4  Middle            테이트
# 3     6955000.0  1  1   6    1  Tuesday   2    4  Middle            테이트
# 4     6672000.0  1  1   6    1  Tuesday   2    4   Later            테이트
# 5     9337000.0  1  1   6    1  Tuesday   2    4   Later            테이트
# 6     6819000.0  1  1   7    4  Tuesday   2    2   First            오모떼
# 7    15689000.0  1  1   7    4  Tuesday   2    2  Middle            오모떼
# 8    25370000.0  1  1   7    4  Tuesday   2    2   Later            오모떼
# 9    16133000.0  1  1   8    1  Tuesday   2    3   First  CERINI by PAT
# 10   30061000.0  1  1   8    1  Tuesday   2    3  Middle  CERINI by PAT
# 11   53542000.0  1  1   8    1  Tuesday   2    3   Later  CERINI by PAT
# 12   16075000.0  1  1   9    1  Tuesday   2    1   First             보코
# 13   25628000.0  1  1   9    1  Tuesday   2    1  Middle             보코
# 14   49270000.0  1  1   9    1  Tuesday   2    1   Later             보코
# 15   48799000.0  1  1  10    1  Tuesday   2    2   First  CERINI by PAT
# 16   97907000.0  1  1  10    1  Tuesday   2    2  Middle  CERINI by PAT
# 17  112972000.0  1  1  10    1  Tuesday   2    2   Later  CERINI by PAT
# 18   24531000.0  1  1  11    4  Tuesday   2    2   First          크로커다일
# 19   49829000.0  1  1  11    4  Tuesday   2    2   Later          크로커다일
# 20   33823000.0  1  1  12    2  Tuesday   2    3   First           에코라믹
# 21   59083000.0  1  1  12    2  Tuesday   2    3  Middle           에코라믹
# 22   99235000.0  1  1  12    2  Tuesday   2    3   Later           에코라믹
# 23   32273000.0  1  1  13    4  Tuesday   2    2   First            오모떼
# 24   79273000.0  1  1  13    4  Tuesday   2    2   Later            오모떼
# 25   11269000.0  1  1  14    1  Tuesday   2    2   First           그렉노먼
# 26   20841000.0  1  1  14    1  Tuesday   2    2   First           그렉노먼
# 27   40526000.0  1  1  14    1  Tuesday   2    2   Later           그렉노먼
# 28   47294000.0  1  1  14    1  Tuesday   2    2   Later           그렉노먼
# 29   14113000.0  1  1  15    2  Tuesday   2    1   First              X
# 30   32395000.0  1  1  15    2  Tuesday   2    1  Middle              X
# 31   39669000.0  1  1  15    2  Tuesday   2    1   Later              X
# 32   60787000.0  1  1  16    2  Tuesday   2    1   First              X
# 33  115457000.0  1  1  16    2  Tuesday   2    1   Later              X
# 34   83893000.0  1  1  16    2  Tuesday   2    1   Later              X
# 35   42239000.0  1  1  17    4  Tuesday   2    1   First      비버리힐스폴로클럽
# 36   73494000.0  1  1  17    4  Tuesday   2    1  Middle      비버리힐스폴로클럽
# 37  107103000.0  1  1  17    4  Tuesday   2    1   Later      비버리힐스폴로클럽
# 38   59050000.0  1  1  18    2  Tuesday   2    1   First              X
# 39   85937000.0  1  1  18    2  Tuesday   2    1  Middle              X
# 40  101468000.0  1  1  18    2  Tuesday   2    1   Later              X
# 41   36620000.0  1  1  19    4  Tuesday   2    3   First             푸마
# 42   69349000.0  1  1  19    4  Tuesday   2    3  Middle             푸마
# 43   84610000.0  1  1  19    4  Tuesday   2    3   Later             푸마
# 44   35519000.0  1  1  20    3  Tuesday   2    3   First             LG
# 45   19123000.0  1  1  20    3  Tuesday   2    3   First             LG
# 46   56859000.0  1  1  20    3  Tuesday   2    3  Middle             LG
# 47   58685000.0  1  1  20    3  Tuesday   2    3  Middle             LG
# 48   68320000.0  1  1  20    3  Tuesday   2    3   Later             LG
# 49   46068000.0  1  1  20    3  Tuesday   2    3   Later             LG

# %%
data[data['브랜드']=='X']['상품군'].value_counts()
# Out:
# 주방      6126
# 의류      4319
# 가전      4115
# 농수축     3881
# 속옷      3852
# 잡화      3687
# 생활용품    2691
# 가구      2275
# 이미용     1296
# 건강기능     774
# 침구       121
# Name: 상품군, dtype: int64

# %%
data.to_csv('0924_ver.csv')

# %%
data[(data.상품군 == '농수축') & (data.상품명.str.contains('셰프'))]
# Out:
#                       방송일시  노출(분)                     상품명  상품군   판매단가  \
# 29     2019-01-01 15:00:00   20.0        뽕셰프 이봉원 특갈비탕 12팩  농수축  60900
# 30     2019-01-01 15:20:00   20.0        뽕셰프 이봉원 특갈비탕 12팩  농수축  60900
# 31     2019-01-01 15:40:00   20.0        뽕셰프 이봉원 특갈비탕 12팩  농수축  60900
# 209    2019-01-03 17:00:00   20.0        뽕셰프 이봉원 특갈비탕 12팩  농수축  60900
# 210    2019-01-03 17:20:00   20.0        뽕셰프 이봉원 특갈비탕 12팩  농수축  60900
# 211    2019-01-03 17:40:00   20.0        뽕셰프 이봉원 특갈비탕 12팩  농수축  60900
# 11127  2019-04-25 17:00:00   20.0  최인선 셰프의 듬뿍 곤드레나물밥 16인분  농수축  49900
# 11128  2019-04-25 17:20:00   20.0  최인선 셰프의 듬뿍 곤드레나물밥 16인분  농수축  49900
# 11129  2019-04-25 17:40:00   20.0  최인선 셰프의 듬뿍 곤드레나물밥 16인분  농수축  49900
#
#               취급액  월   일   시  소비층        요일  휴일  프라임      파트 브랜드
# 29     14113000.0  1   1  15    2   Tuesday   2    1   First   X
# 30     32395000.0  1   1  15    2   Tuesday   2    1  Middle   X
# 31     39669000.0  1   1  15    2   Tuesday   2    1   Later   X
# 209    16350000.0  1   3  17    2  Thursday   0    1   First   X
# 210    33015000.0  1   3  17    2  Thursday   0    1  Middle   X
# 211    27284000.0  1   3  17    2  Thursday   0    1   Later   X
# 11127   8269000.0  4  25  17    2  Thursday   0    1   First   X
# 11128  12878000.0  4  25  17    2  Thursday   0    1  Middle   X
# 11129  13475000.0  4  25  17    2  Thursday   0    1   Later   X

# %%
data[(data.상품군 == '농수축')]
# Out:
#                       방송일시  노출(분)               상품명  상품군   판매단가          취급액  \
# 29     2019-01-01 15:00:00   20.0  뽕셰프 이봉원 특갈비탕 12팩  농수축  60900   14113000.0
# 30     2019-01-01 15:20:00   20.0  뽕셰프 이봉원 특갈비탕 12팩  농수축  60900   32395000.0
# 31     2019-01-01 15:40:00   20.0  뽕셰프 이봉원 특갈비탕 12팩  농수축  60900   39669000.0
# 32     2019-01-01 16:00:00   20.0     국내산 손질갑오징어 8팩  농수축  49900   60787000.0
# 33     2019-01-01 16:20:00   20.0     국내산 손질갑오징어 8팩  농수축  49900  115457000.0
# ...                    ...    ...               ...  ...    ...          ...
# 35308  2019-12-31 11:40:00   20.0        안동간고등어 20팩  농수축  30900   54879000.0
# 35309  2019-12-31 12:00:00   20.0        안동간고등어 20팩  농수축  30900   63460000.0
# 35325  2019-12-31 15:20:00   20.0        제주갈치+참조기세트  농수축  49900   34001000.0
# 35326  2019-12-31 15:40:00   20.0        제주갈치+참조기세트  농수축  49900   54234000.0
# 35327  2019-12-31 16:00:00   20.0        제주갈치+참조기세트  농수축  49900   52313000.0
#
#         월   일   시  소비층       요일  휴일  프라임      파트 브랜드
# 29      1   1  15    2  Tuesday   2    1   First   X
# 30      1   1  15    2  Tuesday   2    1  Middle   X
# 31      1   1  15    2  Tuesday   2    1   Later   X
# 32      1   1  16    2  Tuesday   2    1   First   X
# 33      1   1  16    2  Tuesday   2    1   Later   X
# ...    ..  ..  ..  ...      ...  ..  ...     ...  ..
# 35308  12  31  11    2  Tuesday   0    2  Middle   X
# 35309  12  31  12    2  Tuesday   0    3   Later   X
# 35325  12  31  15    2  Tuesday   0    1   First   X
# 35326  12  31  15    2  Tuesday   0    1  Middle   X
# 35327  12  31  16    2  Tuesday   0    1   Later   X
#
# [3884 rows x 15 columns]

# %%
def Brandset(group):
  name_list= []
  df = data[data['상품군'] == group]
  for words in df['상품명']:
    name_list.append(words)

  brand_set= []
  for name in name_list:
    brand_set.append(name.split()[0])
  brand_set = set(brand_set)

  return brand_set

# %%
Brandset('농수축')
# Out:
# {'(a4)팽현숙의',
#  '19년',
#  'AAB의',
#  'AAC',
#  'AAC한우소머리곰탕양곰탕세트',
#  'AAE',
#  'SPC삼립',
#  '[가격인하]전철우',
#  '[농협]',
#  '[농협안심벌꿀]',
#  '[맛있는',
#  '[바다원]',
#  '[본죽]',
#  '[수협]',
#  '[슬로푸드]',
#  '[영광군수협]',
#  '[통영바다의보물]',
#  '[특등급]',
#  '강레오의',
#  '강원도양구',
#  '거창특등급사과',
#  '고창',
#  '고칼슘검은콩두유48팩+호두아몬드',
#  '구워만든',
#  '국내산',
#  '국내산참조기12팩',
#  '궁중',
#  '김선영',
#  '김정문의',
#  '김정배',
#  '깐깐송도순',
#  '남해바다',
#  '농협안심벌꿀',
#  '더커진거창특등급사과',
#  '멋진밥상',
#  '명인',
#  '목우촌',
#  '바다먹자',
#  '뽕셰프',
#  '사용불가미리구운',
#  '산머루농원',
#  '소들녘',
#  '속초명물',
#  '신세대',
#  '안동간고등어',
#  '영광',
#  '영산포숙성',
#  '영산포숙성홍어회7팩',
#  '예천청결',
#  '옛날',
#  '오세득',
#  '완도꼬마활전복',
#  '완도산',
#  '우리나라',
#  '우리바다',
#  '유귀열의',
#  '이경제원장의',
#  '이만기의',
#  '이보은의',
#  '이봉원',
#  '이정섭의',
#  '임성근의',
#  '자연산',
#  '자이언트킹랍스터',
#  '잔다리',
#  '장보고',
#  '전철우',
#  '제주',
#  '제주갈치+참조기세트',
#  '제주갈치고등어구이세트',
#  '제주바다',
#  '조방할매',
#  '참바다손질낙지+양념장+연포탕육수',
#  '참바다손질낙지100미+양념장+연포탕육수',
#  '창녕',
#  '천수봉명인',
#  '천연담아',
#  '청정수산',
#  '최인선',
#  '캘리포니아',
#  '통뼈',
#  '포항구룡포과메기세트',
#  '피시원',
#  '하늘내린',
#  '하동',
#  '하림',
#  '하림뼈없는양념닭발세트',
#  '현대어찬',
#  '황토방'}

# %%
food = ['팽현숙', '전철우', '농협', '바다원', '본죽', '수협', '강레오', 
        '김선영', '김정문', '김정배', '송도순', '명인', '목우촌', '바다먹자',
        '뽕셰프', '산머루농원', '소들녘', '오세득', '유귀열', '이경제', '이만기',
        '이보은', '이봉원', '이정섭', '임성근', '장보고', '조방할매', '참바다',
        '천수봉명인', '최인선', '피시원', '하늘내린', '하동', '하림', '현대어찬', '황토방']

# %%
brand_list = []
for i in range(len(data)):
    group = data['상품군'].iloc[i]
    name = data['상품명'].iloc[i]
    
    if group == '주방':
        brand_list.append(Brand(kitchen, name))
    elif group == '가전':
        brand_list.append(Brand(digital, name))
    elif group == '의류':
        brand_list.append(Brand(clothes, name))
    elif group == '속옷':
        brand_list.append(Brand(inner, name))
    elif group == '잡화':
        brand_list.append(Brand(stuff, name))
    elif group == '생활용품':
        brand_list.append(Brand(life, name))
    elif group == '가구':
        brand_list.append(Brand(furniture, name))
    elif group == '이미용':
        brand_list.append(Brand(beauty, name))
    elif group == '건강기능':
        brand_list.append(Brand(health, name))
    elif group == '침구':
        brand_list.append(Brand(bed, name))
    elif group == '농수축':
        brand_list.append(Brand(food, name))

# %%
brand_list
# Out:
# ['테이트',
#  '테이트',
#  '테이트',
#  '테이트',
#  '테이트',
#  '테이트',
#  '오모떼',
#  '오모떼',
#  '오모떼',
#  'CERINI by PAT',
#  'CERINI by PAT',
#  'CERINI by PAT',
#  '보코',
#  '보코',
#  '보코',
#  'CERINI by PAT',
#  'CERINI by PAT',
#  'CERINI by PAT',
#  '크로커다일',
#  '크로커다일',
#  '에코라믹',
#  '에코라믹',
#  '에코라믹',
#  '오모떼',
#  '오모떼',
#  '그렉노먼',
#  '그렉노먼',
#  '그렉노먼',
#  '그렉노먼',
#  '뽕셰프',
#  '뽕셰프',
#  '뽕셰프',
#  None,
#  None,
#  '농협',
#  '비버리힐스폴로클럽',
#  '비버리힐스폴로클럽',
#  '비버리힐스폴로클럽',
#  None,
#  None,
#  None,
#  '푸마',
#  '푸마',
#  '푸마',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  '마리노블',
#  '마리노블',
#  '마리노블',
#  '헤스티지',
#  '헤스티지',
#  '로베르타',
#  '로베르타',
#  '로베르타',
#  '그렉노먼',
#  '그렉노먼',
#  '그렉노먼',
#  '그렉노먼',
#  '그렉노먼',
#  '그렉노먼',
#  '레이프릴',
#  '레이프릴',
#  '레이프릴',
#  '벨라홈',
#  '벨라홈',
#  '벨라홈',
#  '종근당건강',
#  '종근당건강',
#  '종근당건강',
#  '오모떼',
#  '오모떼',
#  '오모떼',
#  'NNF',
#  'NNF',
#  'NNF',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '헤스티지',
#  '헤스티지',
#  '린나이',
#  '린나이',
#  '린나이',
#  '린나이',
#  '린나이',
#  '린나이',
#  '린나이',
#  '린나이',
#  '린나이',
#  '린나이',
#  '린나이',
#  '린나이',
#  '하늘내린',
#  '하늘내린',
#  '하늘내린',
#  '오모떼',
#  '오모떼',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  '바다먹자',
#  '바다먹자',
#  '바다먹자',
#  '키친플라워',
#  '키친플라워',
#  '키친플라워',
#  '피시원',
#  '피시원',
#  '피시원',
#  '푸마',
#  '푸마',
#  '푸마',
#  '푸마',
#  '푸마',
#  '푸마',
#  '푸마',
#  '푸마',
#  '푸마',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  '크로커다일',
#  '크로커다일',
#  '크로커다일',
#  '테이트',
#  '테이트',
#  '테이트',
#  '테이트',
#  '푸마',
#  '푸마',
#  '푸마',
#  '에펨',
#  '에펨',
#  '에펨',
#  '에펨',
#  '에펨',
#  '에펨',
#  None,
#  None,
#  None,
#  '엘렌실라',
#  '엘렌실라',
#  '엘렌실라',
#  '로베르타',
#  '로베르타',
#  '로베르타',
#  '오모떼',
#  '오모떼',
#  '보코',
#  '보코',
#  '보코',
#  '종근당건강',
#  '종근당건강',
#  '종근당건강',
#  '비버리힐스폴로클럽',
#  '비버리힐스폴로클럽',
#  '비버리힐스폴로클럽',
#  '한일',
#  '한일',
#  '한일',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  None,
#  None,
#  None,
#  '뽕셰프',
#  '뽕셰프',
#  '뽕셰프',
#  None,
#  None,
#  None,
#  '푸마',
#  '푸마',
#  '푸마',
#  '푸마',
#  '푸마',
#  '푸마',
#  '푸마',
#  '푸마',
#  '푸마',
#  '노비타',
#  '노비타',
#  '노비타',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  '로베르타',
#  '로베르타',
#  '로베르타',
#  '그렉노먼',
#  '그렉노먼',
#  '그렉노먼',
#  '그렉노먼',
#  '그렉노먼',
#  '그렉노먼',
#  '마리노블',
#  '마리노블',
#  '마리노블',
#  '벨라홈',
#  '벨라홈',
#  '벨라홈',
#  '제주농장',
#  '제주농장',
#  '제주농장',
#  '코이모',
#  '코이모',
#  '코이모',
#  '로베르타',
#  '로베르타',
#  '로베르타',
#  '린나이',
#  '린나이',
#  '린나이',
#  '린나이',
#  '린나이',
#  '린나이',
#  '린나이',
#  '린나이',
#  '린나이',
#  '린나이',
#  '린나이',
#  '린나이',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '오모떼',
#  '오모떼',
#  None,
#  None,
#  None,
#  '한일',
#  '한일',
#  '한일',
#  '오모떼',
#  '오모떼',
#  '오모떼',
#  '소들녘',
#  '소들녘',
#  '소들녘',
#  '하늘내린',
#  '하늘내린',
#  '하늘내린',
#  '키친플라워',
#  '키친플라워',
#  '키친플라워',
#  '피시원',
#  '피시원',
#  '피시원',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  '비버리힐스폴로클럽',
#  '비버리힐스폴로클럽',
#  '비버리힐스폴로클럽',
#  '크로커다일',
#  '크로커다일',
#  '크로커다일',
#  '그렉노먼',
#  '그렉노먼',
#  '그렉노먼',
#  '그렉노먼',
#  '그렉노먼',
#  '그렉노먼',
#  '헤스티지',
#  '헤스티지',
#  '스포메틱스',
#  '스포메틱스',
#  '스포메틱스',
#  '가이거',
#  '가이거',
#  '가이거',
#  '가이거',
#  '가이거',
#  '가이거',
#  '스칼프솔루션',
#  '스칼프솔루션',
#  '스칼프솔루션',
#  '아문센',
#  '아문센',
#  '아문센',
#  '아문센',
#  '아문센',
#  '아문센',
#  '마담팰리스',
#  '마담팰리스',
#  '마담팰리스',
#  '오모떼',
#  '오모떼',
#  '보코',
#  '보코',
#  '보코',
#  'CERINI by PAT',
#  'CERINI by PAT',
#  'CERINI by PAT',
#  '키친플라워',
#  '키친플라워',
#  '키친플라워',
#  '에코라믹',
#  '에코라믹',
#  '에코라믹',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  '오모떼',
#  '오모떼',
#  '농협',
#  '농협',
#  '농협',
#  None,
#  None,
#  None,
#  '바다먹자',
#  '바다먹자',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '푸마',
#  '푸마',
#  '푸마',
#  '푸마',
#  '푸마',
#  '푸마',
#  '푸마',
#  '푸마',
#  '푸마',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  '푸마',
#  '푸마',
#  '푸마',
#  'K-SWISS',
#  'K-SWISS',
#  'K-SWISS',
#  'K-SWISS',
#  'K-SWISS',
#  'K-SWISS',
#  '비버리힐스폴로클럽',
#  '비버리힐스폴로클럽',
#  '비버리힐스폴로클럽',
#  '팽현숙',
#  '팽현숙',
#  '팽현숙',
#  '종근당건강',
#  '종근당건강',
#  '종근당건강',
#  '마리끌레르',
#  '마리끌레르',
#  '마리끌레르',
#  '로베르타',
#  '로베르타',
#  '로베르타',
#  '보코',
#  '보코',
#  '보코',
#  '오모떼',
#  '오모떼',
#  '오모떼',
#  '헤스티지',
#  '헤스티지',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '아리스토우',
#  '아리스토우',
#  '아리스토우',
#  '비버리힐스폴로클럽',
#  '비버리힐스폴로클럽',
#  '비버리힐스폴로클럽',
#  '오모떼',
#  '오모떼',
#  '소들녘',
#  '소들녘',
#  '소들녘',
#  None,
#  None,
#  None,
#  '푸마',
#  '푸마',
#  '푸마',
#  '푸마',
#  '푸마',
#  '푸마',
#  '푸마',
#  '푸마',
#  '푸마',
#  '노비타',
#  '노비타',
#  '노비타',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  '크로커다일',
#  '크로커다일',
#  '크로커다일',
#  '마리노블',
#  '마리노블',
#  '마리노블',
#  '스위스밀리터리',
#  '스위스밀리터리',
#  '도네이',
#  '도네이',
#  '도네이',
#  '도네이',
#  '도네이',
#  '도네이',
#  '레이프릴',
#  '레이프릴',
#  '레이프릴',
#  '엘렌실라',
#  '엘렌실라',
#  '엘렌실라',
#  '보코',
#  '보코',
#  '보코',
#  '비버리힐스폴로클럽',
#  '비버리힐스폴로클럽',
#  '비버리힐스폴로클럽',
#  '오모떼',
#  '오모떼',
#  '린나이',
#  '린나이',
#  '린나이',
#  '린나이',
#  '린나이',
#  '린나이',
#  '린나이',
#  '린나이',
#  '린나이',
#  '린나이',
#  '린나이',
#  '린나이',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '소들녘',
#  '소들녘',
#  '소들녘',
#  '한일',
#  '한일',
#  '한일',
#  '농협',
#  '농협',
#  '농협',
#  None,
#  None,
#  None,
#  '에코라믹',
#  '에코라믹',
#  '에코라믹',
#  None,
#  None,
#  None,
#  '노비타',
#  '노비타',
#  '노비타',
#  '푸마',
#  '푸마',
#  '푸마',
#  '푸마',
#  '푸마',
#  '푸마',
#  '푸마',
#  '푸마',
#  '푸마',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  '로베르타',
#  '로베르타',
#  '로베르타',
#  '헤스티지',
#  '헤스티지',
#  'K-SWISS',
#  'K-SWISS',
#  'K-SWISS',
#  'K-SWISS',
#  'K-SWISS',
#  'K-SWISS',
#  '푸마',
#  '푸마',
#  '푸마',
#  '스칼프솔루션',
#  '스칼프솔루션',
#  '스칼프솔루션',
#  '마담팰리스',
#  '마담팰리스',
#  '마담팰리스',
#  '쿠미투니카',
#  '쿠미투니카',
#  '엘렌실라',
#  '엘렌실라',
#  '엘렌실라',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '오모떼',
#  '오모떼',
#  '하늘내린',
#  '하늘내린',
#  '하늘내린',
#  None,
#  None,
#  None,
#  '농협',
#  '농협',
#  '농협',
#  None,
#  None,
#  None,
#  '키친플라워',
#  '키친플라워',
#  '키친플라워',
#  '바다먹자',
#  '바다먹자',
#  '바다먹자',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '푸마',
#  '푸마',
#  '푸마',
#  '푸마',
#  '푸마',
#  '푸마',
#  '푸마',
#  '푸마',
#  '푸마',
#  None,
#  None,
#  None,
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  '마리노블',
#  '마리노블',
#  '마리노블',
#  '크로커다일',
#  '크로커다일',
#  '크로커다일',
#  '아리스토우',
#  '아리스토우',
#  '아리스토우',
#  '가이거',
#  '가이거',
#  '가이거',
#  '가이거',
#  '가이거',
#  '가이거',
#  '보코',
#  '보코',
#  '보코',
#  '종근당건강',
#  '종근당건강',
#  '종근당건강',
#  '레이프릴',
#  '레이프릴',
#  '레이프릴',
#  '린나이',
#  '린나이',
#  '린나이',
#  '린나이',
#  '린나이',
#  '린나이',
#  '린나이',
#  '린나이',
#  '린나이',
#  '린나이',
#  '린나이',
#  '린나이',
#  '엘렌실라',
#  '엘렌실라',
#  '엘렌실라',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '에코라믹',
#  '에코라믹',
#  '농협',
#  '농협',
#  '농협',
#  '하늘내린',
#  '하늘내린',
#  '하늘내린',
#  '한일',
#  '한일',
#  '한일',
#  '피시원',
#  '피시원',
#  '피시원',
#  '농협',
#  '농협',
#  '농협',
#  None,
#  None,
#  None,
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  '노비타',
#  '노비타',
#  '노비타',
#  '로베르타',
#  '로베르타',
#  '로베르타',
#  '헤스티지',
#  '헤스티지',
#  'CERINI by PAT',
#  'CERINI by PAT',
#  'CERINI by PAT',
#  '비버리힐스폴로클럽',
#  '비버리힐스폴로클럽',
#  '비버리힐스폴로클럽',
#  '레이프릴',
#  '레이프릴',
#  '레이프릴',
#  '메디쉴드',
#  '메디쉴드',
#  '메디쉴드',
#  '메디쉴드',
#  '메디쉴드',
#  '메디쉴드',
#  '마담팰리스',
#  '마담팰리스',
#  '마담팰리스',
#  '아리스토우',
#  '아리스토우',
#  '아리스토우',
#  '오모떼',
#  '오모떼',
#  '린나이',
#  '린나이',
#  '린나이',
#  '린나이',
#  '린나이',
#  '린나이',
#  '린나이',
#  '린나이',
#  '린나이',
#  '린나이',
#  '린나이',
#  '린나이',
#  '종근당건강',
#  '종근당건강',
#  '종근당건강',
#  '농협',
#  '농협',
#  '농협',
#  '키친플라워',
#  '키친플라워',
#  '키친플라워',
#  None,
#  None,
#  None,
#  '소들녘',
#  '소들녘',
#  '소들녘',
#  None,
#  None,
#  None,
#  '소들녘',
#  '소들녘',
#  '소들녘',
#  '바다먹자',
#  '바다먹자',
#  '바다먹자',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '쿠첸',
#  '크로커다일',
#  '크로커다일',
#  '크로커다일',
#  None,
#  None,
#  None,
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  '마리노블',
#  '마리노블',
#  '마리노블',
#  '레이프릴',
#  '레이프릴',
#  '레이프릴',
#  '마리끌레르',
#  '마리끌레르',
#  '마리끌레르',
#  '에버라스트',
#  '에버라스트',
#  '에버라스트',
#  '에버라스트',
#  '에버라스트',
#  '에버라스트',
#  '테이트',
#  '테이트',
#  '테이트',
#  '테이트',
#  '테이트',
#  '테이트',
#  '오모떼',
#  '오모떼',
#  '보코',
#  '보코',
#  '보코',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '더블유베일',
#  '더블유베일',
#  None,
#  None,
#  None,
#  '한일',
#  '한일',
#  '한일',
#  '농협',
#  '농협',
#  '농협',
#  '하늘내린',
#  '하늘내린',
#  '하늘내린',
#  '명인',
#  '명인',
#  '명인',
#  '바다먹자',
#  '바다먹자',
#  '바다먹자',
#  '키친플라워',
#  '키친플라워',
#  '키친플라워',
#  '카파',
#  '카파',
#  '카파',
#  '카파',
#  '카파',
#  '카파',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'LG',
#  'CERINI by PAT',
#  'CERINI by PAT',
#  'CERINI by PAT',
#  '로이몬스터',
#  '로이몬스터',
#  '삼성',
#  '삼성',
#  '삼성',
#  '삼성',
#  '삼성',
#  '삼성',
#  '삼성',
#  '삼성',
#  '삼성',
#  '삼성',
#  '아리스토우',
#  '아리스토우',
#  '아리스토우',
#  '아리스토우',
#  '아리스토우',
#  '아리스토우',
#  '그렉노먼',
#  '그렉노먼',
#  '그렉노먼',
#  '그렉노먼',
#  '그렉노먼',
#  '그렉노먼',
#  '보코',
#  '보코',
#  '보코',
#  '쿠미투니카',
#  '쿠미투니카',
#  '쿠미투니카',
#  '가이거',
#  '가이거',
#  '가이거',
#  '가이거',
#  '가이거',
#  '가이거',
#  'CERINI by PAT',
#  'CERINI by PAT',
#  'CERINI by PAT',
#  '헤스티지',
#  '헤스티지',
#  '오모떼',
#  '오모떼',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '쿠쿠',
#  '비버리힐스폴로클럽',
#  '비버리힐스폴로클럽',
#  '비버리힐스폴로클럽',
#  '린나이',
#  ...]

# %%
len(brand_list)
# Out:
# 35375

# %%
data['브랜드'] = brand_list
data
# Out:
#                       방송일시  노출(분)             상품명 상품군    판매단가         취급액   월  \
# 0      2019-01-01 06:00:00   20.0   테이트 남성 셀린니트3종  의류   39900   2099000.0   1
# 1      2019-01-01 06:00:00   20.0   테이트 여성 셀린니트3종  의류   39900   4371000.0   1
# 2      2019-01-01 06:20:00   20.0   테이트 남성 셀린니트3종  의류   39900   3262000.0   1
# 3      2019-01-01 06:20:00   20.0   테이트 여성 셀린니트3종  의류   39900   6955000.0   1
# 4      2019-01-01 06:40:00   20.0   테이트 남성 셀린니트3종  의류   39900   6672000.0   1
# ...                    ...    ...             ...  ..     ...         ...  ..
# 35370  2019-12-31 23:20:00   20.0   일시불쿠첸압력밥솥 6인용  주방  148000   1664000.0  12
# 35371  2019-12-31 23:40:00   20.0  무이자쿠첸압력밥솥 10인용  주방  178000   9149000.0  12
# 35372  2019-12-31 23:40:00   20.0  일시불쿠첸압력밥솥 10인용  주방  168000  15282000.0  12
# 35373  2019-12-31 23:40:00   20.0   무이자쿠첸압력밥솥 6인용  주방  158000   2328000.0  12
# 35374  2019-12-31 23:40:00   20.0   일시불쿠첸압력밥솥 6인용  주방  148000  10157000.0  12
#
#         일   시  소비층       요일  휴일  프라임      파트  브랜드
# 0       1   6    1  Tuesday   2    4   First  테이트
# 1       1   6    1  Tuesday   2    4   First  테이트
# 2       1   6    1  Tuesday   2    4  Middle  테이트
# 3       1   6    1  Tuesday   2    4  Middle  테이트
# 4       1   6    1  Tuesday   2    4   Later  테이트
# ...    ..  ..  ...      ...  ..  ...     ...  ...
# 35370  31  23    2  Tuesday   0    4   First   쿠첸
# 35371  31  23    2  Tuesday   0    4   Later   쿠첸
# 35372  31  23    2  Tuesday   0    4   Later   쿠첸
# 35373  31  23    2  Tuesday   0    4   Later   쿠첸
# 35374  31  23    2  Tuesday   0    4   Later   쿠첸
#
# [35375 rows x 15 columns]

# %%
data.head(50)
# Out:
#                    방송일시  노출(분)                            상품명  상품군    판매단가  \
# 0   2019-01-01 06:00:00   20.0                  테이트 남성 셀린니트3종   의류   39900
# 1   2019-01-01 06:00:00   20.0                  테이트 여성 셀린니트3종   의류   39900
# 2   2019-01-01 06:20:00   20.0                  테이트 남성 셀린니트3종   의류   39900
# 3   2019-01-01 06:20:00   20.0                  테이트 여성 셀린니트3종   의류   39900
# 4   2019-01-01 06:40:00   20.0                  테이트 남성 셀린니트3종   의류   39900
# 5   2019-01-01 06:40:00   20.0                  테이트 여성 셀린니트3종   의류   39900
# 6   2019-01-01 07:00:00   20.0               오모떼 레이스 파운데이션 브라   속옷   59000
# 7   2019-01-01 07:20:00   20.0               오모떼 레이스 파운데이션 브라   속옷   59000
# 8   2019-01-01 07:40:00   20.0               오모떼 레이스 파운데이션 브라   속옷   59000
# 9   2019-01-01 08:00:00   20.0  CERINI by PAT 남성 소프트 기모 릴렉스팬츠   의류   59900
# 10  2019-01-01 08:20:00   20.0  CERINI by PAT 남성 소프트 기모 릴렉스팬츠   의류   59900
# 11  2019-01-01 08:40:00   20.0  CERINI by PAT 남성 소프트 기모 릴렉스팬츠   의류   59900
# 12  2019-01-01 09:00:00   20.0                    보코 리버시블 무스탕   의류   79000
# 13  2019-01-01 09:20:00   20.0                    보코 리버시블 무스탕   의류   79000
# 14  2019-01-01 09:40:00   20.0                    보코 리버시블 무스탕   의류   79000
# 15  2019-01-01 10:00:00   20.0  CERINI by PAT 남성 풀패키지 기모니트 3종   의류   79900
# 16  2019-01-01 10:20:00   20.0  CERINI by PAT 남성 풀패키지 기모니트 3종   의류   79900
# 17  2019-01-01 10:40:00   20.0  CERINI by PAT 남성 풀패키지 기모니트 3종   의류   79900
# 18  2019-01-01 11:00:00   20.0      크로커다일 The 편안한 코튼 브라팬티 4세트   속옷   69900
# 19  2019-01-01 11:20:00   20.0      크로커다일 The 편안한 코튼 브라팬티 4세트   속옷   69900
# 20  2019-01-01 12:00:00   20.0               에코라믹 통주물 스톤 냄비세트   주방   60900
# 21  2019-01-01 12:20:00   20.0               에코라믹 통주물 스톤 냄비세트   주방   60900
# 22  2019-01-01 12:40:00   20.0               에코라믹 통주물 스톤 냄비세트   주방   60900
# 23  2019-01-01 13:00:00   30.0       오모떼 360도 텐션업 레이스 패키지 시즌4   속옷  109000
# 24  2019-01-01 13:30:00   30.0       오모떼 360도 텐션업 레이스 패키지 시즌4   속옷  109000
# 25  2019-01-01 14:00:00   30.0            그렉노먼 남성 구스다운 롱 벤치코트   의류  119000
# 26  2019-01-01 14:00:00   30.0            그렉노먼 여성 구스다운 롱 벤치코트   의류  119000
# 27  2019-01-01 14:30:00   30.0            그렉노먼 남성 구스다운 롱 벤치코트   의류  119000
# 28  2019-01-01 14:30:00   30.0            그렉노먼 여성 구스다운 롱 벤치코트   의류  119000
# 29  2019-01-01 15:00:00   20.0               뽕셰프 이봉원 특갈비탕 12팩  농수축   60900
# 30  2019-01-01 15:20:00   20.0               뽕셰프 이봉원 특갈비탕 12팩  농수축   60900
# 31  2019-01-01 15:40:00   20.0               뽕셰프 이봉원 특갈비탕 12팩  농수축   60900
# 32  2019-01-01 16:00:00   20.0                  국내산 손질갑오징어 8팩  농수축   49900
# 33  2019-01-01 16:20:00   20.0                  국내산 손질갑오징어 8팩  농수축   49900
# 34  2019-01-01 16:40:00   20.0              멋진밥상 흥양농협 햅쌀 20kg  농수축   61000
# 35  2019-01-01 17:00:00   20.0     비버리힐스폴로클럽 남성기초세트(2018FW골드)  이미용   39800
# 36  2019-01-01 17:20:00   20.0     비버리힐스폴로클럽 남성기초세트(2018FW골드)  이미용   39800
# 37  2019-01-01 17:40:00   20.0     비버리힐스폴로클럽 남성기초세트(2018FW골드)  이미용   39800
# 38  2019-01-01 18:00:00   20.0                 우리바다 손질왕꼬막 24팩  농수축   39900
# 39  2019-01-01 18:20:00   20.0                 우리바다 손질왕꼬막 24팩  농수축   39900
# 40  2019-01-01 18:40:00   20.0                 우리바다 손질왕꼬막 24팩  농수축   39900
# 41  2019-01-01 19:00:00   20.0         푸마 에어핏 서포트 브라세트 15종+4종   속옷  119000
# 42  2019-01-01 19:20:00   20.0         푸마 에어핏 서포트 브라세트 15종+4종   속옷  119000
# 43  2019-01-01 19:40:00   20.0         푸마 에어핏 서포트 브라세트 15종+4종   속옷  119000
# 44  2019-01-01 20:00:00   20.0                 일시불 LG 통돌이 세탁기   가전  439000
# 45  2019-01-01 20:00:00   20.0                 무이자 LG 통돌이 세탁기   가전  489000
# 46  2019-01-01 20:20:00   20.0                 일시불 LG 통돌이 세탁기   가전  439000
# 47  2019-01-01 20:20:00   20.0                 무이자 LG 통돌이 세탁기   가전  489000
# 48  2019-01-01 20:40:00   20.0                 일시불 LG 통돌이 세탁기   가전  439000
# 49  2019-01-01 20:40:00   20.0                 무이자 LG 통돌이 세탁기   가전  489000
#
#             취급액  월  일   시  소비층       요일  휴일  프라임      파트            브랜드
# 0     2099000.0  1  1   6    1  Tuesday   2    4   First            테이트
# 1     4371000.0  1  1   6    1  Tuesday   2    4   First            테이트
# 2     3262000.0  1  1   6    1  Tuesday   2    4  Middle            테이트
# 3     6955000.0  1  1   6    1  Tuesday   2    4  Middle            테이트
# 4     6672000.0  1  1   6    1  Tuesday   2    4   Later            테이트
# 5     9337000.0  1  1   6    1  Tuesday   2    4   Later            테이트
# 6     6819000.0  1  1   7    4  Tuesday   2    2   First            오모떼
# 7    15689000.0  1  1   7    4  Tuesday   2    2  Middle            오모떼
# 8    25370000.0  1  1   7    4  Tuesday   2    2   Later            오모떼
# 9    16133000.0  1  1   8    1  Tuesday   2    3   First  CERINI by PAT
# 10   30061000.0  1  1   8    1  Tuesday   2    3  Middle  CERINI by PAT
# 11   53542000.0  1  1   8    1  Tuesday   2    3   Later  CERINI by PAT
# 12   16075000.0  1  1   9    1  Tuesday   2    1   First             보코
# 13   25628000.0  1  1   9    1  Tuesday   2    1  Middle             보코
# 14   49270000.0  1  1   9    1  Tuesday   2    1   Later             보코
# 15   48799000.0  1  1  10    1  Tuesday   2    2   First  CERINI by PAT
# 16   97907000.0  1  1  10    1  Tuesday   2    2  Middle  CERINI by PAT
# 17  112972000.0  1  1  10    1  Tuesday   2    2   Later  CERINI by PAT
# 18   24531000.0  1  1  11    4  Tuesday   2    2   First          크로커다일
# 19   49829000.0  1  1  11    4  Tuesday   2    2   Later          크로커다일
# 20   33823000.0  1  1  12    2  Tuesday   2    3   First           에코라믹
# 21   59083000.0  1  1  12    2  Tuesday   2    3  Middle           에코라믹
# 22   99235000.0  1  1  12    2  Tuesday   2    3   Later           에코라믹
# 23   32273000.0  1  1  13    4  Tuesday   2    2   First            오모떼
# 24   79273000.0  1  1  13    4  Tuesday   2    2   Later            오모떼
# 25   11269000.0  1  1  14    1  Tuesday   2    2   First           그렉노먼
# 26   20841000.0  1  1  14    1  Tuesday   2    2   First           그렉노먼
# 27   40526000.0  1  1  14    1  Tuesday   2    2   Later           그렉노먼
# 28   47294000.0  1  1  14    1  Tuesday   2    2   Later           그렉노먼
# 29   14113000.0  1  1  15    2  Tuesday   2    1   First            뽕셰프
# 30   32395000.0  1  1  15    2  Tuesday   2    1  Middle            뽕셰프
# 31   39669000.0  1  1  15    2  Tuesday   2    1   Later            뽕셰프
# 32   60787000.0  1  1  16    2  Tuesday   2    1   First           None
# 33  115457000.0  1  1  16    2  Tuesday   2    1   Later           None
# 34   83893000.0  1  1  16    2  Tuesday   2    1   Later             농협
# 35   42239000.0  1  1  17    4  Tuesday   2    1   First      비버리힐스폴로클럽
# 36   73494000.0  1  1  17    4  Tuesday   2    1  Middle      비버리힐스폴로클럽
# 37  107103000.0  1  1  17    4  Tuesday   2    1   Later      비버리힐스폴로클럽
# 38   59050000.0  1  1  18    2  Tuesday   2    1   First           None
# 39   85937000.0  1  1  18    2  Tuesday   2    1  Middle           None
# 40  101468000.0  1  1  18    2  Tuesday   2    1   Later           None
# 41   36620000.0  1  1  19    4  Tuesday   2    3   First             푸마
# 42   69349000.0  1  1  19    4  Tuesday   2    3  Middle             푸마
# 43   84610000.0  1  1  19    4  Tuesday   2    3   Later             푸마
# 44   35519000.0  1  1  20    3  Tuesday   2    3   First             LG
# 45   19123000.0  1  1  20    3  Tuesday   2    3   First             LG
# 46   56859000.0  1  1  20    3  Tuesday   2    3  Middle             LG
# 47   58685000.0  1  1  20    3  Tuesday   2    3  Middle             LG
# 48   68320000.0  1  1  20    3  Tuesday   2    3   Later             LG
# 49   46068000.0  1  1  20    3  Tuesday   2    3   Later             LG

# %%
data.to_csv('0924_ver.csv')

# %%
data[(data.상품군 == '농수축')]['브랜드'].isnull().sum()
# Out:
# 2178
